# %% [markdown]
# # Demo notebook
#
# This notebook grabs a random image from the site `lorempixel.com`
# and shows it.
# Rerunning the notebook should get a new image.

# %%
import requests
from IPython.display import Image

# %%
r = requests.get('http://lorempixel.com/800/800/')
Image(data=r.content)
